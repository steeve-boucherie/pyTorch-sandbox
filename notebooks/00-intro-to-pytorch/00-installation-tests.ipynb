# %% [markdown]
# Installation tests from https://pytorch.org/get-started/locally/

# %%
import torch

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.6019, 0.4898, 0.8472],
#         [0.7475, 0.4739, 0.1797],
#         [0.5451, 0.4241, 0.2873],
#         [0.4174, 0.7868, 0.5679],
#         [0.6855, 0.1131, 0.2602]])

# %%
torch.cuda.is_available()
# Out:
# True
